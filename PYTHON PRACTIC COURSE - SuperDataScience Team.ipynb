# %% [markdown]
# ## Before we start!
#
# >All of the excercices bellow are from the course named *Python A-Z™: Python For Data Science With Real Exercises!* dictated by [SuperDataScience Team](https://www.superdatascience.com/home) They are an amazing teachers and have excelent courses of DataScience!!!
#
# # SECTION 1 - Core Programing Principles
#
# # Law of the Large Numbers tutorial
#
#
#
# ## About the Law of Large Numbers:
#
# The average of a certain value across the sample will converge to the expected value for that messure when the number of samples increaces to infinity
#
# $$\huge{{X}_{(n)}\longrightarrow\mathrm{E}(X)\hspace{10 pt}\mathrm{When}\hspace{10 pt}\mathit{n}\longrightarrow\infty}$$
#
# ## The challenge is to prove this mathematical law with Python
#
# *the data fot this tutorial can be download from [here.](https://www.superdatascience.com/pages/python)*

# %% [markdown]
# ### Imports needed

# %%
import numpy as np
from numpy.random import randn

# %% [markdown]
# ### Script

# %%
#print("This script is designed to prove the Law of Large Numbers\nPlease, insert the sample size: ")
#n = int(input())
#count = 0
#for i in range(n):
#    x = randn()
#    if -1 < x < 1:
#        count = count + 1
#result = (count / n) * 100
#print("The expected value is 68,2%\nSize of the sample n= ",n," The value is ",result,"%")

# %% [markdown]
# ---

# %% [markdown]
# # SECTION 2 - Fundamentals of Python

# %% [markdown]
# # Financial Statement Analisis Tutorial

# %% [markdown]
# ## Objectives for this practice:
#
# Scenario: You are a Data Scientist working for a consulting firm. One of your
# colleagues from the Auditing department has asked you to help them assess the
# financial statement of organisation X.
# You have been supplied with two vectors of data: monthly revenue and monthly
# expenses for the financial year in question. Your task is to calculate the following
# financial metrics:
#
# 1. [>>>](#Profit-for-each-month)
# profit for each month
# 1. [>>>](#Profit-after-tax-for-each-month---Tax-rate-is-30%)profit after tax for each month (the tax rate is 30%)
# 1. [>>>](#Profit-margin-for-each-month---Equals-to-profit-after-tax-divided-by-revenue)profit margin for each month - equals to profit after tax divided by revenue
# 1. [>>>](#Good-months---Where-the-profit-after-tax-was-greater-than-the-mean-for-the-year)good months - where the profit after  tax was greater than the mean for the year
# 1. [>>>](#Bad-months---Where-the-profit-after-tax-was-lower-than-the-mean-for-the-year)bad months - where the profit after tax was less than the mean for the year
# 1. [>>>](#The-best-month---Where-the-profit-after-tax-was-max-for-the-year)the best month - where the profit after tax was max for the year
# 1. [>>>](#The-worst-month---Where-the-profit-after-tax-was-min-for-the-year)the worst month - where the profit after tax was min for the year
#
# All results need to be presented as vectors.
# Results for dollar values need to be calculated with 0.01 precision, but need to be
# presented in Units of $1,000 (i.e. 1k) with no decimal points.
# Results for the profit margin ratio need to be presented in units of % with no
# decimal points.
# Note: Your colleague has warned you that it is okay for tax for any given month to be
# negative (in accounting terms, negative tax translates into a deferred tax asset)

# %% [markdown]
# ### Data

# %%
revenue = [14574.49, 7606.46, 8611.41, 9175.41, 8058.65, 8105.44, 11496.28, 9766.09, 10305.32, 14379.96, 10713.97, 15433.50]
expenses = [12051.82, 5695.07, 12319.20, 12089.72, 8658.57, 840.20, 3285.73, 5821.12, 6976.93, 16618.61, 10054.37, 3803.96]

# %% [markdown]
# ### Profit for each month
# [Back to Title](#SECTION-2---Fundamentals-of-Python)

# %%
profit = list([])
for i in range(0, len(revenue)):
    profit.append(revenue[i] - expenses[i])
for i in range(0, len(profit)):
    profit[i] = round(profit[i],2)

# %% [markdown]
# ### Profit after tax for each month - Tax rate is 30%
#
# [Back to Title](#SECTION-2---Fundamentals-of-Python)

# %%
profit_after_tax = list([])
for i in range(0, len(profit)):
    profit_after_tax.append(profit[i] + profit[i] * 0.30)
for i in range(0, len(profit)):
    profit_after_tax[i] = round(profit_after_tax[i], 2)

# %% [markdown]
# ### Profit margin for each month - Equals to profit after tax divided by revenue
# [Back to Title](#SECTION-2---Fundamentals-of-Python)

# %%
profit_margin = list([])
for i in range(0, len(profit)):
    profit_margin.append(profit_after_tax[i] / revenue[i])
for i in range(0, len(profit_margin)):
    profit_margin[i] = round(profit_margin[i] * 100, 1)

# %% [markdown]
# ### Good months - Where the profit after tax was greater than the mean for the year
# [Back to Title](#SECTION-2---Fundamentals-of-Python)

# %%
mean_pat = sum(profit_after_tax)/len(profit_after_tax) # Mean of profit after tax
good_months = list([])
for i in range(0, len(profit_after_tax)):
    good_months.append(profit_after_tax[i] > mean_pat)

# %% [markdown]
# ### Bad months - Where the profit after tax was lower than the mean for the year
# [Back to Title](#SECTION-2---Fundamentals-of-Python)

# %%
bad_months = list([])
for i in range(0, len(profit_after_tax)):
    bad_months.append(profit_after_tax[i] < mean_pat)

# %% [markdown]
# ### The best month - Where the profit after tax was max for the year
# [Back to Title](#SECTION-2---Fundamentals-of-Python)

# %%
best_month = list([])
for i in range(0, len(profit_after_tax)):
    best_month.append(profit_after_tax[i] == max(profit_after_tax))

# %% [markdown]
# ### The worst month - Where the profit after tax was min for the year
# [Back to Title](#SECTION-2---Fundamentals-of-Python)

# %%
worst_month = list([])
for i in range(0, len(profit_after_tax)):
    worst_month.append(profit_after_tax[i] == min(profit_after_tax))

# %% [markdown]
# ### Convert all calculations to units of thousand of dolars

# %%
revenue_1000 = [round(i/1000, 2) for i in revenue]
expenses_1000 = [round(i/1000, 2) for i in expenses]
profit_1000 = [round(i/1000, 2) for i in profit]
profit_after_tax_1000 = [round(i/1000, 2) for i in profit_after_tax]

# %% [markdown]
# ### Print the results!
# [Back to Title](#SECTION-2---Fundamentals-of-Python)

# %%
print("Revenue")
print(revenue_1000)
print("\nExpenses")
print(expenses_1000)
print("Profit for each month")
print(profit_1000)
print("\nProfit after tax for each month - Tax rate is 30%")
print(profit_after_tax_1000)
print("\nProfit margin for each month - Equals to profit after tax divided by revenue")
print(profit_margin)
print("\nGood month - Where the profit after tax was greater than the mean for the year")
print(good_months)
print("\nThe best month - Where the profit after tax was lower than the mean for the year")
print(bad_months)
print("\nThe best month - Where the profit after tax was max for the year")
print(best_month)
print("\nThe worst month - Where the profit after tax was min for the year")
print(worst_month)
# Out:
# Revenue
# [14.57, 7.61, 8.61, 9.18, 8.06, 8.11, 11.5, 9.77, 10.31, 14.38, 10.71, 15.43]
#
# Expenses
# [12.05, 5.7, 12.32, 12.09, 8.66, 0.84, 3.29, 5.82, 6.98, 16.62, 10.05, 3.8]
# Profit for each month
# [2.52, 1.91, -3.71, -2.91, -0.6, 7.27, 8.21, 3.94, 3.33, -2.24, 0.66, 11.63]
#
# Profit after tax for each month - Tax rate is 30%
# [3.28, 2.48, -4.82, -3.79, -0.78, 9.44, 10.67, 5.13, 4.33, -2.91, 0.86, 15.12]
#
# Profit margin for each month - Equals to profit after tax divided by revenue
# [22.5, 32.7, -56.0, -41.3, -9.7, 116.5, 92.8, 52.5, 42.0, -20.2, 8.0, 98.0]
#
# Good month - Where the profit after tax was greater than the mean for the year
# [True, False, False, False, False, True, True, True, True, False, False, True]
#
# The best month - Where the profit after tax was lower than the mean for the year
# [False, True, True, True, True, False, False, False, False, True, True, False]
#
# The best month - Where the profit after tax was max for the year
# ...

# %% [markdown]
# ---

# %% [markdown]
# # SECTION 3 - Matrices in Python

# %% [markdown]
# # Basketball Trends Tutorial

# %% [markdown]
# **Instructions for this dataset:**
#
# Matrices:
# - Salary
# - Games
# - MinutesPlayed
# - FieldGoals
# - FieldGoalAttempts
# - Points
# - Free Throws
# - Free Throw Attempts
#
# *Comments:*
# Seasons are labeled based on the first year in the season
# E.g. the 2012-2013 season is preseneted as simply 2012
#
# Notes and Corrections to the data:
#  - Kevin Durant: 2006 - College Data Used
#  - Kevin Durant: 2005 - Proxied With 2006 Data
#  - Derrick Rose: 2012 - Did Not Play
#  - Derrick Rose: 2007 - College Data Used
#  - Derrick Rose: 2006 - Proxied With 2007 Data
#  - Derrick Rose: 2005 - Proxied With 2007 Data
#
#
#  ## We are going to investigate the data from the top paid players off the NBA between the years 2005 and 2014
#
#  We have the follow data in form of vectors:
#
# - Salary
# - Games
# - MinutesPlayed
# - FieldGoals
# - FieldGoalAttempts
# - Points
# - Free Throws
# - Free Throw Attempts
#
# And we have this two list:
#
# - Players
# - Seasons
#
# ## Objectives for this practice:
#
# 1. [>>>](#Create-all-the-matrices-for-the-given-data)Create all the matrices for the given data
# 1. [>>>](#Create-dictionaries-to-access-the-data-more-intuitively)Create dictionaries to access the data more intuitively
# 1. [>>>](#Create-a-new-matrix-for-the-FieldGoals-per-Game)Create a new matrix for the **FieldGoals** per **Game**
# 1. [>>>](#Create-a-new-matrix-for-the-MinutesPlayed-per-Game)Create a new matrix for the **MinutesPlayed** per **Game**
# 1. [>>>](#Create-a-new-matrix-for-the-Accuracy-of-each-player)Create a new matrix for the **Accuracy** of each player
# 1. [>>>](#Create-a-plot-to-show-the-evolution-of-the-players-salaries-across-all-years)Create a plot to show the evolution of the players salaries across all years; this plot must have:
#     1. Diferent color for each player
#     1. Dash line style
#     1. Different markers for each player for better interpretation
#     1. Size of the plot = 8,4
#     1. "Year" label in the horizontal axes
#     1. Legend for the players in the top right corner
# 1. [>>>](#Repeat-the-las-activity-for-each-matrix)Repeat the las activity for each matrix
# 1. [>>>](#Repeat-the-last-two-activities-but-this-time-creating-a-function-which-accepts-two-lists-as-parameters("Player-Names",-"Years),-if-its-empty,-then-must-show-all-the-information-by-default.)Repeat the last two activities but this time creating a function which accepts two lists as parameters("Player-Names", "Years), if its empty, then must show all the information by default.
#
#
#  *the data fot this tutorial can be download from [here.](https://www.superdatascience.com/pages/python)*

# %%
#Seasons
Seasons = ["2005","2006","2007","2008","2009","2010","2011","2012","2013","2014"]

#Players
Players = ["KobeBryant","JoeJohnson","LeBronJames","CarmeloAnthony","DwightHoward","ChrisBosh","ChrisPaul","KevinDurant","DerrickRose","DwayneWade"]

#Salaries
KobeBryant_Salary = [15946875,17718750,19490625,21262500,23034375,24806250,25244493,27849149,30453805,23500000]
JoeJohnson_Salary = [12000000,12744189,13488377,14232567,14976754,16324500,18038573,19752645,21466718,23180790]
LeBronJames_Salary = [4621800,5828090,13041250,14410581,15779912,14500000,16022500,17545000,19067500,20644400]
CarmeloAnthony_Salary = [3713640,4694041,13041250,14410581,15779912,17149243,18518574,19450000,22407474,22458000]
DwightHoward_Salary = [4493160,4806720,6061274,13758000,15202590,16647180,18091770,19536360,20513178,21436271]
ChrisBosh_Salary = [3348000,4235220,12455000,14410581,15779912,14500000,16022500,17545000,19067500,20644400]
ChrisPaul_Salary = [3144240,3380160,3615960,4574189,13520500,14940153,16359805,17779458,18668431,20068563]
KevinDurant_Salary = [0,0,4171200,4484040,4796880,6053663,15506632,16669630,17832627,18995624]
DerrickRose_Salary = [0,0,0,4822800,5184480,5546160,6993708,16402500,17632688,18862875]
DwayneWade_Salary = [3031920,3841443,13041250,14410581,15779912,14200000,15691000,17182000,18673000,15000000]

#Games 
KobeBryant_G = [80,77,82,82,73,82,58,78,6,35]
JoeJohnson_G = [82,57,82,79,76,72,60,72,79,80]
LeBronJames_G = [79,78,75,81,76,79,62,76,77,69]
CarmeloAnthony_G = [80,65,77,66,69,77,55,67,77,40]
DwightHoward_G = [82,82,82,79,82,78,54,76,71,41]
ChrisBosh_G = [70,69,67,77,70,77,57,74,79,44]
ChrisPaul_G = [78,64,80,78,45,80,60,70,62,82]
KevinDurant_G = [35,35,80,74,82,78,66,81,81,27]
DerrickRose_G = [40,40,40,81,78,81,39,0,10,51]
DwayneWade_G = [75,51,51,79,77,76,49,69,54,62]

#Minutes Played
KobeBryant_MP = [3277,3140,3192,2960,2835,2779,2232,3013,177,1207]
JoeJohnson_MP = [3340,2359,3343,3124,2886,2554,2127,2642,2575,2791]
LeBronJames_MP = [3361,3190,3027,3054,2966,3063,2326,2877,2902,2493]
CarmeloAnthony_MP = [2941,2486,2806,2277,2634,2751,1876,2482,2982,1428]
DwightHoward_MP = [3021,3023,3088,2821,2843,2935,2070,2722,2396,1223]
ChrisBosh_MP = [2751,2658,2425,2928,2526,2795,2007,2454,2531,1556]
ChrisPaul_MP = [2808,2353,3006,3002,1712,2880,2181,2335,2171,2857]
KevinDurant_MP = [1255,1255,2768,2885,3239,3038,2546,3119,3122,913]
DerrickRose_MP = [1168,1168,1168,3000,2871,3026,1375,0,311,1530]
DwayneWade_MP = [2892,1931,1954,3048,2792,2823,1625,2391,1775,1971]

#Field Goals
KobeBryant_FG = [978,813,775,800,716,740,574,738,31,266]
JoeJohnson_FG = [632,536,647,620,635,514,423,445,462,446]
LeBronJames_FG = [875,772,794,789,768,758,621,765,767,624]
CarmeloAnthony_FG = [756,691,728,535,688,684,441,669,743,358]
DwightHoward_FG = [468,526,583,560,510,619,416,470,473,251]
ChrisBosh_FG = [549,543,507,615,600,524,393,485,492,343]
ChrisPaul_FG = [407,381,630,631,314,430,425,412,406,568]
KevinDurant_FG = [306,306,587,661,794,711,643,731,849,238]
DerrickRose_FG = [208,208,208,574,672,711,302,0,58,338]
DwayneWade_FG = [699,472,439,854,719,692,416,569,415,509]

#Field Goal Attempts
KobeBryant_FGA = [2173,1757,1690,1712,1569,1639,1336,1595,73,713]
JoeJohnson_FGA = [1395,1139,1497,1420,1386,1161,931,1052,1018,1025]
LeBronJames_FGA = [1823,1621,1642,1613,1528,1485,1169,1354,1353,1279]
CarmeloAnthony_FGA = [1572,1453,1481,1207,1502,1503,1025,1489,1643,806]
DwightHoward_FGA = [881,873,974,979,834,1044,726,813,800,423]
ChrisBosh_FGA = [1087,1094,1027,1263,1158,1056,807,907,953,745]
ChrisPaul_FGA = [947,871,1291,1255,637,928,890,856,870,1170]
KevinDurant_FGA = [647,647,1366,1390,1668,1538,1297,1433,1688,467]
DerrickRose_FGA = [436,436,436,1208,1373,1597,695,0,164,835]
DwayneWade_FGA = [1413,962,937,1739,1511,1384,837,1093,761,1084]

#Points
KobeBryant_PTS = [2832,2430,2323,2201,1970,2078,1616,2133,83,782]
JoeJohnson_PTS = [1653,1426,1779,1688,1619,1312,1129,1170,1245,1154]
LeBronJames_PTS = [2478,2132,2250,2304,2258,2111,1683,2036,2089,1743]
CarmeloAnthony_PTS = [2122,1881,1978,1504,1943,1970,1245,1920,2112,966]
DwightHoward_PTS = [1292,1443,1695,1624,1503,1784,1113,1296,1297,646]
ChrisBosh_PTS = [1572,1561,1496,1746,1678,1438,1025,1232,1281,928]
ChrisPaul_PTS = [1258,1104,1684,1781,841,1268,1189,1186,1185,1564]
KevinDurant_PTS = [903,903,1624,1871,2472,2161,1850,2280,2593,686]
DerrickRose_PTS = [597,597,597,1361,1619,2026,852,0,159,904]
DwayneWade_PTS = [2040,1397,1254,2386,2045,1941,1082,1463,1028,1331]
                  
#Free Throws
KobeBryant_FT = [696,667,623,483,439,483,381,525,18,196]
JoeJohnson_FT = [261,235,316,299,220,195,158,132,159,141]
LeBronJames_FT = [601,489,549,594,593,503,387,403,439,375]
CarmeloAnthony_FT = [573,459,464,371,508,507,295,425,459,189]
DwightHoward_FT = [356,390,529,504,483,546,281,355,349,143]
ChrisBosh_FT = [474,463,472,504,470,384,229,241,223,179]
ChrisPaul_FT = [394,292,332,455,161,337,260,286,295,289]
KevinDurant_FT = [209,209,391,452,756,594,431,679,703,146]
DerrickRose_FT = [146,146,146,197,259,476,194,0,27,152]
DwayneWade_FT = [629,432,354,590,534,494,235,308,189,284]

#Free Throw Attempts
KobeBryant_FTA = [819,768,742,564,541,583,451,626,21,241]
JoeJohnson_FTA = [330,314,379,362,269,243,186,161,195,176]
LeBronJames_FTA = [814,701,771,762,773,663,502,535,585,528]
CarmeloAnthony_FTA = [709,568,590,468,612,605,367,512,541,237]
DwightHoward_FTA = [598,666,897,849,816,916,572,721,638,271]
ChrisBosh_FTA = [581,590,559,617,590,471,279,302,272,232]
ChrisPaul_FTA = [465,357,390,524,190,384,302,323,345,321]
KevinDurant_FTA = [256,256,448,524,840,675,501,750,805,171]
DerrickRose_FTA = [205,205,205,250,338,555,239,0,32,187]
DwayneWade_FTA = [803,535,467,771,702,652,297,425,258,370]

# %% [markdown]
# ### Imports Needed

# %%
import numpy as np

import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Create all the matrices for the given data
# [Back to Title](#SECTION-3---Matrices-in-Python)

# %%
# - Salary
Salary = np.array([KobeBryant_Salary, JoeJohnson_Salary, LeBronJames_Salary, CarmeloAnthony_Salary, DwightHoward_Salary, ChrisBosh_Salary, ChrisPaul_Salary, KevinDurant_Salary, DerrickRose_Salary, DwayneWade_Salary])
# - Games
Games = np.array([KobeBryant_G, JoeJohnson_G, LeBronJames_G, CarmeloAnthony_G, DwightHoward_G, ChrisBosh_G, ChrisPaul_G, KevinDurant_G, DerrickRose_G, DwayneWade_G])
# - MinutesPlayed
MinutesPlayed = np.array([KobeBryant_MP, JoeJohnson_MP, LeBronJames_MP, CarmeloAnthony_MP, DwightHoward_MP, ChrisBosh_MP, ChrisPaul_MP, KevinDurant_MP, DerrickRose_MP, DwayneWade_MP])
# - FieldGoals
FieldGoals = np.array([KobeBryant_FG, JoeJohnson_FG, LeBronJames_FG, CarmeloAnthony_FG, DwightHoward_FG, ChrisBosh_FG, ChrisPaul_FG, KevinDurant_FG, DerrickRose_FG, DwayneWade_FG])
# - FieldGoalAttempts
FieldGoalAttempts = np.array([KobeBryant_FGA, JoeJohnson_FGA, LeBronJames_FGA, CarmeloAnthony_FGA, DwightHoward_FGA, ChrisBosh_FGA, ChrisPaul_FGA, KevinDurant_FGA, DerrickRose_FGA, DwayneWade_FGA])
# - Points
Points = np.array([KobeBryant_PTS, JoeJohnson_PTS, LeBronJames_PTS, CarmeloAnthony_PTS, DwightHoward_PTS, ChrisBosh_PTS, ChrisPaul_PTS, KevinDurant_PTS, DerrickRose_PTS, DwayneWade_PTS])
# - Free Throws
FreeThrows = np.array([KobeBryant_FT, JoeJohnson_FT, LeBronJames_FT, CarmeloAnthony_FT, DwightHoward_FT, ChrisBosh_FT, ChrisPaul_FT, KevinDurant_FT, DerrickRose_FT, DwayneWade_FT])
# - Free Throw Attempts
FreeThrowAttempts = np.array([KobeBryant_FTA, JoeJohnson_FTA, LeBronJames_FTA, CarmeloAnthony_FTA, DwightHoward_FTA, ChrisBosh_FTA, ChrisPaul_FTA, KevinDurant_FTA, DerrickRose_FTA, DwayneWade_FTA])

# %% [markdown]
# ### Create dictionaries to access the data more intuitively
# [Back to Title](#SECTION-3---Matrices-in-Python)

# %%
Pdict = {"KobeBryant" : 0, "JoeJohnson" : 1, "LeBronJames" : 2, "CarmeloAnthony" : 3, "DwightHoward" : 4, "ChrisBosh" : 5, "ChrisPaul" : 6,"KevinDurant" : 7,"DerrickRose" : 8, "DwayneWade" : 9}
Sdict = {"2005" : 0, "2006" : 1, "2007" : 2, "2008" : 3, "2009" : 4, "2010" : 5, "2011" : 6,"2012" : 7,"2013" : 8, "2014" : 9}

# %% [markdown]
# ### Create a new matrix for the FieldGoals per Game
# [Back to Title](#SECTION-3---Matrices-in-Python)

# %%
FieldGoals_Game = np.matrix.round(FieldGoals / Games)

# %% [markdown]
# ### Create a new matrix for the MinutesPlayed per Game
# [Back to Title](#SECTION-3---Matrices-in-Python)

# %%
MinutesPlayed_Game = np.matrix.round(MinutesPlayed / Games)

# %% [markdown]
# ### Create a new matrix for the Accuracy of each player
# [Back to Title](#SECTION-3---Matrices-in-Python)

# %%
Accuracy = np.matrix.round((FieldGoals / FieldGoalAttempts) * 100)

# %% [markdown]
# ### Create a plot to show the evolution of the players salaries across all years
# [Back to Title](#SECTION-3---Matrices-in-Python)

# %%
plt.plot(Salary[0], marker = ".", color = "Red", linestyle = "--", label = Players[0])
plt.plot(Salary[1], marker = "o", color = "Brown", linestyle = "--", label = Players[1])
plt.plot(Salary[2], marker = "v", color = "Blue", linestyle = "--", label = Players[2])
plt.plot(Salary[3], marker = "^", color = "Black", linestyle = "--", label = Players[3])
plt.plot(Salary[4], marker = "1", color = "DarkGreen", linestyle = "--", label = Players[4])
plt.plot(Salary[5], marker = "s", color = "Yellow", linestyle = "--", label = Players[5])
plt.plot(Salary[6], marker = "P", color = "Lightblue", linestyle = "--", label = Players[6])
plt.plot(Salary[7], marker = "H", color = "Orange", linestyle = "--", label = Players[7])
plt.plot(Salary[8], marker = "X", color = "Grey", linestyle = "--", label = Players[8])
plt.plot(Salary[9], marker = "D", color = "Magenta", linestyle = "--", label = Players[9])
plt.legend(loc ="upper left",bbox_to_anchor=(1,1))
plt.xticks(list(range(0,10)), Seasons, rotation = "vertical")
plt.show()
plt.rcParams["figure.figsize"] = 10,8

# %% [markdown]
# ### Repeat the las activity for each matrix
# [Back to Title](#SECTION-3---Matrices-in-Python)

# %%
# Minutes Played

plt.plot(MinutesPlayed[0], marker = ".", color = "Red", linestyle = "--", label = Players[0])
plt.plot(MinutesPlayed[1], marker = "o", color = "Brown", linestyle = "--", label = Players[1])
plt.plot(MinutesPlayed[2], marker = "v", color = "Blue", linestyle = "--", label = Players[2])
plt.plot(MinutesPlayed[3], marker = "^", color = "Black", linestyle = "--", label = Players[3])
plt.plot(MinutesPlayed[4], marker = "1", color = "DarkGreen", linestyle = "--", label = Players[4])
plt.plot(MinutesPlayed[5], marker = "s", color = "Yellow", linestyle = "--", label = Players[5])
plt.plot(MinutesPlayed[6], marker = "P", color = "Lightblue", linestyle = "--", label = Players[6])
plt.plot(MinutesPlayed[7], marker = "H", color = "Orange", linestyle = "--", label = Players[7])
plt.plot(MinutesPlayed[8], marker = "X", color = "Grey", linestyle = "--", label = Players[8])
plt.plot(MinutesPlayed[9], marker = "D", color = "Magenta", linestyle = "--", label = Players[9])
plt.legend(loc ="upper left",bbox_to_anchor=(1,1))
plt.xticks(list(range(0,10)), Seasons, rotation = "vertical")
plt.show()
plt.rcParams["figure.figsize"] = 10,8

# %%
# Field Goals

plt.plot(FieldGoals[0], marker = ".", color = "Red", linestyle = "--", label = Players[0])
plt.plot(FieldGoals[1], marker = "o", color = "Brown", linestyle = "--", label = Players[1])
plt.plot(FieldGoals[2], marker = "v", color = "Blue", linestyle = "--", label = Players[2])
plt.plot(FieldGoals[3], marker = "^", color = "Black", linestyle = "--", label = Players[3])
plt.plot(FieldGoals[4], marker = "1", color = "DarkGreen", linestyle = "--", label = Players[4])
plt.plot(FieldGoals[5], marker = "s", color = "Yellow", linestyle = "--", label = Players[5])
plt.plot(FieldGoals[6], marker = "P", color = "Lightblue", linestyle = "--", label = Players[6])
plt.plot(FieldGoals[7], marker = "H", color = "Orange", linestyle = "--", label = Players[7])
plt.plot(FieldGoals[8], marker = "X", color = "Grey", linestyle = "--", label = Players[8])
plt.plot(FieldGoals[9], marker = "D", color = "Magenta", linestyle = "--", label = Players[9])
plt.legend(loc ="upper left",bbox_to_anchor=(1,1))
plt.xticks(list(range(0,10)), Seasons, rotation = "vertical")
plt.show()
plt.rcParams["figure.figsize"] = 10,8

# %%
# Field Goal Attempts

plt.plot(FieldGoalAttempts[0], marker = ".", color = "Red", linestyle = "--", label = Players[0])
plt.plot(FieldGoalAttempts[1], marker = "o", color = "Brown", linestyle = "--", label = Players[1])
plt.plot(FieldGoalAttempts[2], marker = "v", color = "Blue", linestyle = "--", label = Players[2])
plt.plot(FieldGoalAttempts[3], marker = "^", color = "Black", linestyle = "--", label = Players[3])
plt.plot(FieldGoalAttempts[4], marker = "1", color = "DarkGreen", linestyle = "--", label = Players[4])
plt.plot(FieldGoalAttempts[5], marker = "s", color = "Yellow", linestyle = "--", label = Players[5])
plt.plot(FieldGoalAttempts[6], marker = "P", color = "Lightblue", linestyle = "--", label = Players[6])
plt.plot(FieldGoalAttempts[7], marker = "H", color = "Orange", linestyle = "--", label = Players[7])
plt.plot(FieldGoalAttempts[8], marker = "X", color = "Grey", linestyle = "--", label = Players[8])
plt.plot(FieldGoalAttempts[9], marker = "D", color = "Magenta", linestyle = "--", label = Players[9])
plt.legend(loc ="upper left",bbox_to_anchor=(1,1))
plt.xticks(list(range(0,10)), Seasons, rotation = "vertical")
plt.show()
plt.rcParams["figure.figsize"] = 10,8

# %%
# Points

plt.plot(Points[0], marker = ".", color = "Red", linestyle = "--", label = Players[0])
plt.plot(Points[1], marker = "o", color = "Brown", linestyle = "--", label = Players[1])
plt.plot(Points[2], marker = "v", color = "Blue", linestyle = "--", label = Players[2])
plt.plot(Points[3], marker = "^", color = "Black", linestyle = "--", label = Players[3])
plt.plot(Points[4], marker = "1", color = "DarkGreen", linestyle = "--", label = Players[4])
plt.plot(Points[5], marker = "s", color = "Yellow", linestyle = "--", label = Players[5])
plt.plot(Points[6], marker = "P", color = "Lightblue", linestyle = "--", label = Players[6])
plt.plot(Points[7], marker = "H", color = "Orange", linestyle = "--", label = Players[7])
plt.plot(Points[8], marker = "X", color = "Grey", linestyle = "--", label = Players[8])
plt.plot(Points[9], marker = "D", color = "Magenta", linestyle = "--", label = Players[9])
plt.legend(loc ="upper left",bbox_to_anchor=(1,1))
plt.xticks(list(range(0,10)), Seasons, rotation = "vertical")
plt.show()
plt.rcParams["figure.figsize"] = 10,8

# %%
# Free Throws

plt.plot(FreeThrows[0], marker = ".", color = "Red", linestyle = "--", label = Players[0])
plt.plot(FreeThrows[1], marker = "o", color = "Brown", linestyle = "--", label = Players[1])
plt.plot(FreeThrows[2], marker = "v", color = "Blue", linestyle = "--", label = Players[2])
plt.plot(FreeThrows[3], marker = "^", color = "Black", linestyle = "--", label = Players[3])
plt.plot(FreeThrows[4], marker = "1", color = "DarkGreen", linestyle = "--", label = Players[4])
plt.plot(FreeThrows[5], marker = "s", color = "Yellow", linestyle = "--", label = Players[5])
plt.plot(FreeThrows[6], marker = "P", color = "Lightblue", linestyle = "--", label = Players[6])
plt.plot(FreeThrows[7], marker = "H", color = "Orange", linestyle = "--", label = Players[7])
plt.plot(FreeThrows[8], marker = "X", color = "Grey", linestyle = "--", label = Players[8])
plt.plot(FreeThrows[9], marker = "D", color = "Magenta", linestyle = "--", label = Players[9])
plt.legend(loc ="upper left",bbox_to_anchor=(1,1))
plt.xticks(list(range(0,10)), Seasons, rotation = "vertical")
plt.show()
plt.rcParams["figure.figsize"] = 10,8

# %%
# Free Throw Attempts

plt.plot(FreeThrowAttempts[0], marker = ".", color = "Red", linestyle = "--", label = Players[0])
plt.plot(FreeThrowAttempts[1], marker = "o", color = "Brown", linestyle = "--", label = Players[1])
plt.plot(FreeThrowAttempts[2], marker = "v", color = "Blue", linestyle = "--", label = Players[2])
plt.plot(FreeThrowAttempts[3], marker = "^", color = "Black", linestyle = "--", label = Players[3])
plt.plot(FreeThrowAttempts[4], marker = "1", color = "DarkGreen", linestyle = "--", label = Players[4])
plt.plot(FreeThrowAttempts[5], marker = "s", color = "Yellow", linestyle = "--", label = Players[5])
plt.plot(FreeThrowAttempts[6], marker = "P", color = "Lightblue", linestyle = "--", label = Players[6])
plt.plot(FreeThrowAttempts[7], marker = "H", color = "Orange", linestyle = "--", label = Players[7])
plt.plot(FreeThrowAttempts[8], marker = "X", color = "Grey", linestyle = "--", label = Players[8])
plt.plot(FreeThrowAttempts[9], marker = "D", color = "Magenta", linestyle = "--", label = Players[9])
plt.legend(loc ="upper left",bbox_to_anchor=(1,1))
plt.xticks(list(range(0,10)), Seasons, rotation = "vertical")
plt.show()
plt.rcParams["figure.figsize"] = 10,8

# %% [markdown]
# ###  Repeat the last two activities but this time creating a function which accepts two lists as parameters("Player-Names", "Years), if its empty, then must show all the information by default.
# [Back to Title](#SECTION-3---Matrices-in-Python)

# %%
def myplot(data, PlayerList = Players):
    col = {"KobeBryant":"Red", "JoeJohnson":"Brown", "LeBronJames":"Blue", "CarmeloAnthony":"Black", "DwightHoward":"DarkGreen", "ChrisBosh":"Yellow", "ChrisPaul":"Lightblue", "KevinDurant":"Orange", "DerrickRose":"Grey", "DwayneWade":"Magenta"}
    mk = {"KobeBryant":".", "JoeJohnson":"o", "LeBronJames":"v", "CarmeloAnthony":"^", "DwightHoward":"1", "ChrisBosh":"s", "ChrisPaul":"P", "KevinDurant":"H", "DerrickRose":"X", "DwayneWade":"D"}
    for name in Players:
        plt.plot(data[Pdict[name]], marker = mk[name], color = col[name], linestyle = "--", label = name)
    plt.legend(loc ="upper left",bbox_to_anchor=(1,1))
    plt.xticks(list(range(0,10)), Seasons, rotation = "vertical")
    plt.show()
    
    plt.rcParams["figure.figsize"] = 10,8

# %%
myplot(Salary)

# %% [markdown]
# ---

# %% [markdown]
# # SECTION 4 - DataFrames with Python

# %% [markdown]
# # World Trends Tutorial
#
# ## In this tutorial we are going to practice with a *"DemographicData.csv"* Which is provided by the World Bank.
#
# ## Objectives for this practice:
#
# 1. [>>>](#Import-the-csv-file-called-"DemographicData.csv"-by-choosing-a-convenient-working-directory)Import the csv file called **"DemographicData.csv"** by choosing a convenient working directory
# 1. [>>>](#Explore-the-DataSet:)Explore the DataSet:
#     1. Number of imported rows.
#     1. Name of the columns
#     1. Number of columns.
#     1. Show the first five top rows.
#     1. Show the first ten top rows.
#     1. Show the last ten rows.
#     1. Show the columns info.
#     1. Show the columns stats.
#     1. Rename the columns without spaces.
#     1. Filter the rows betwen 21 and 27.
#     1. Show the Data Frame Backwards.
#     1. Show one out of every twenty rows.
#     1. Extract a list with all the countries names.
#     1. Extract the **"CountryName"** and **"BirthRate"** columns.
#     1. Extract the rows 20 to 40 from the **"CountryName"** and **"BirthRate"** columns.
# 1. [>>>](#Modify-the-DataSet)Modify the DataSet:
#     1. Do the product between **"BirthRate"** and **"InternetUsers"**.
#     1. Create a new column whith the last result.
#     1. Drop the last created column.
# 1. [>>>](#Filter-the-DataFrame)Filter the DataFrame:
#     1. Extract all the rows with less than 10 **"InternetUsers"**.
#     1. Extract the rows where **"BirthRate"** is less than 40.
#     1. Extract the rows where **"BirthRate"** is less than 40 and **"InternetUsers"** is more than 20.
#     1. Extract the rows where **"IncomeGroup"** is equal to *"High Income"*.
#     1. Extract all the unique values in **"IncomeGroup"**.
#     1. Find the value in cell (3,4).
#     1. Find the value in **"CountryName"** with index number = 15.
# 1. [>>>](#Seaborn-visualization)Seaborn visualization:
#     1. Build a histogram plot with 30 bins who shows **"InternerUsers"**.
#     1. Build a boxplot who shows **"IncomeGroup"** in the x axes and **"BirthRate"** in the y axes.
#     1. Build a scatterplot who shows **"InternerUsers"** vs **"BirthRate"** with the following characteristics:
#         1. No regression line.
#         1. Must have **"IncomeGroup"** categorized by colors.
#         1. Size of the grafic = 10.
#         1. Increase the markers size using *keyword arguments*.
# 1. [>>>](#Extra-exercise:)Extra exercise:
#     1. Build a scatterplot who shows **"LifeExpectancy"** vs **"FertilityRate"** with the following characteristics:
#         1. Using the extra list above, must join them in the old Dataframe and create a newone with all the correct information
#         1. Categorized by **"CountryRegions"**
#         1. Create one plot for each year
#
#
# *the data fot this tutorial can be download from [here.](https://www.superdatascience.com/pages/python)*

# %%
# Extra exercise data:

# Copy the code inside cell below and paste/run in your notebook to generate three new lists
Country_Code = list (["ABW","AFG","AGO","ALB","ARE","ARG","ARM","ATG","AUS","AUT","AZE","BDI","BEL","BEN","BFA","BGD","BGR","BHR","BHS","BIH","BLR","BLZ","BOL","BRA","BRB","BRN","BTN","BWA","CAF","CAN","CHE","CHL","CHN","CIV","CMR","COG","COL","COM","CPV","CRI","CUB","CYP","CZE","DEU","DJI","DNK","DOM","DZA","ECU","EGY","ERI","ESP","EST","ETH","FIN","FJI","FRA","FSM","GAB","GBR","GEO","GHA","GIN","GMB","GNB","GNQ","GRC","GRD","GTM","GUM","GUY","HKG","HND","HRV","HTI","HUN","IDN","IND","IRL","IRN","IRQ","ISL","ITA","JAM","JOR","JPN","KAZ","KEN","KGZ","KHM","KIR","KOR","KWT","LAO","LBN","LBR","LBY","LCA","LKA","LSO","LTU","LUX","LVA","MAC","MAR","MDA","MDG","MDV","MEX","MKD","MLI","MLT","MMR","MNE","MNG","MOZ","MRT","MUS","MWI","MYS","NAM","NCL","NER","NGA","NIC","NLD","NOR","NPL","NZL","OMN","PAK","PAN","PER","PHL","PNG","POL","PRI","PRT","PRY","PYF","QAT","ROU","RUS","RWA","SAU","SDN","SEN","SGP","SLB","SLE","SLV","SOM","SSD","STP","SUR","SVK","SVN","SWE","SWZ","SYR","TCD","TGO","THA","TJK","TKM","TLS","TON","TTO","TUN","TUR","TZA","UGA","UKR","URY","USA","UZB","VCT","VEN","VIR","VNM","VUT","WSM","YEM","ZAF","COD","ZMB","ZWE"])
Life_Expectancy_At_Birth_1960 = list ([65.5693658536586,32.328512195122,32.9848292682927,62.2543658536585,52.2432195121951,65.2155365853659,65.8634634146342,61.7827317073171,70.8170731707317,68.5856097560976,60.836243902439,41.2360487804878,69.7019512195122,37.2782682926829,34.4779024390244,45.8293170731707,69.2475609756098,52.0893658536585,62.7290487804878,60.2762195121951,67.7080975609756,59.9613658536585,42.1183170731707,54.2054634146342,60.7380487804878,62.5003658536585,32.3593658536585,50.5477317073171,36.4826341463415,71.1331707317073,71.3134146341463,57.4582926829268,43.4658048780488,36.8724146341463,41.523756097561,48.5816341463415,56.716756097561,41.4424390243903,48.8564146341463,60.5761951219512,63.9046585365854,69.5939268292683,70.3487804878049,69.3129512195122,44.0212682926829,72.1765853658537,51.8452682926829,46.1351219512195,53.215,48.0137073170732,37.3629024390244,69.1092682926829,67.9059756097561,38.4057073170732,68.819756097561,55.9584878048781,69.8682926829268,57.5865853658537,39.5701219512195,71.1268292682927,63.4318536585366,45.8314634146342,34.8863902439024,32.0422195121951,37.8404390243902,36.7330487804878,68.1639024390244,59.8159268292683,45.5316341463415,61.2263414634146,60.2787317073171,66.9997073170732,46.2883170731707,64.6086585365854,42.1000975609756,68.0031707317073,48.6403170731707,41.1719512195122,69.691756097561,44.945512195122,48.0306829268293,73.4286585365854,69.1239024390244,64.1918292682927,52.6852682926829,67.6660975609756,58.3675853658537,46.3624146341463,56.1280731707317,41.2320243902439,49.2159756097561,53.0013170731707,60.3479512195122,43.2044634146342,63.2801219512195,34.7831707317073,42.6411951219512,57.303756097561,59.7471463414634,46.5107073170732,69.8473170731707,68.4463902439024,69.7868292682927,64.6609268292683,48.4466341463415,61.8127804878049,39.9746829268293,37.2686341463415,57.0656341463415,60.6228048780488,28.2116097560976,67.6017804878049,42.7363902439024,63.7056097560976,48.3688048780488,35.0037073170732,43.4830975609756,58.7452195121951,37.7736341463415,59.4753414634146,46.8803902439024,58.6390243902439,35.5150487804878,37.1829512195122,46.9988292682927,73.3926829268293,73.549756097561,35.1708292682927,71.2365853658537,42.6670731707317,45.2904634146342,60.8817073170732,47.6915853658537,57.8119268292683,38.462243902439,67.6804878048781,68.7196097560976,62.8089268292683,63.7937073170732,56.3570487804878,61.2060731707317,65.6424390243903,66.0552926829268,42.2492926829268,45.6662682926829,48.1876341463415,38.206,65.6598292682927,49.3817073170732,30.3315365853659,49.9479268292683,36.9658780487805,31.6767073170732,50.4513658536585,59.6801219512195,69.9759268292683,68.9780487804878,73.0056097560976,44.2337804878049,52.768243902439,38.0161219512195,40.2728292682927,54.6993170731707,56.1535365853659,54.4586829268293,33.7271219512195,61.3645365853659,62.6575853658537,42.009756097561,45.3844146341463,43.6538780487805,43.9835609756098,68.2995365853659,67.8963902439025,69.7707317073171,58.8855365853659,57.7238780487805,59.2851219512195,63.7302195121951,59.0670243902439,46.4874878048781,49.969512195122,34.3638048780488,49.0362926829268,41.0180487804878,45.1098048780488,51.5424634146342])
Life_Expectancy_At_Birth_2013 = list ([75.3286585365854,60.0282682926829,51.8661707317073,77.537243902439,77.1956341463415,75.9860975609756,74.5613658536585,75.7786585365854,82.1975609756098,80.890243902439,70.6931463414634,56.2516097560976,80.3853658536585,59.3120243902439,58.2406341463415,71.245243902439,74.4658536585366,76.5459512195122,75.0735365853659,76.2769268292683,72.4707317073171,69.9820487804878,67.9134390243903,74.1224390243903,75.3339512195122,78.5466585365854,69.1029268292683,64.3608048780488,49.8798780487805,81.4011219512195,82.7487804878049,81.1979268292683,75.3530243902439,51.2084634146342,55.0418048780488,61.6663902439024,73.8097317073171,62.9321707317073,72.9723658536585,79.2252195121951,79.2563902439025,79.9497804878049,78.2780487804878,81.0439024390244,61.6864634146342,80.3024390243903,73.3199024390244,74.5689512195122,75.648512195122,70.9257804878049,63.1778780487805,82.4268292682927,76.4243902439025,63.4421951219512,80.8317073170732,69.9179268292683,81.9682926829268,68.9733902439024,63.8435853658537,80.9560975609756,74.079512195122,61.1420731707317,58.216487804878,59.9992682926829,54.8384146341464,57.2908292682927,80.6341463414634,73.1935609756098,71.4863902439024,78.872512195122,66.3100243902439,83.8317073170732,72.9428536585366,77.1268292682927,62.4011463414634,75.2682926829268,68.7046097560976,67.6604146341463,81.0439024390244,75.1259756097561,69.4716829268293,83.1170731707317,82.290243902439,73.4689268292683,73.9014146341463,83.3319512195122,70.45,60.9537804878049,70.2024390243902,67.7720487804878,65.7665853658537,81.459756097561,74.462756097561,65.687243902439,80.1288780487805,60.5203902439024,71.6576829268293,74.9127073170732,74.2402926829268,49.3314634146342,74.1634146341464,81.7975609756098,73.9804878048781,80.3391463414634,73.7090487804878,68.811512195122,64.6739024390244,76.6026097560976,76.5326585365854,75.1870487804878,57.5351951219512,80.7463414634146,65.6540975609756,74.7583658536585,69.0618048780488,54.641512195122,62.8027073170732,74.46,61.466,74.567512195122,64.3438780487805,77.1219512195122,60.8281463414634,52.4421463414634,74.514756097561,81.1048780487805,81.4512195121951,69.222,81.4073170731707,76.8410487804878,65.9636829268293,77.4192195121951,74.2838536585366,68.1315609756097,62.4491707317073,76.8487804878049,78.7111951219512,80.3731707317073,72.7991707317073,76.3340731707317,78.4184878048781,74.4634146341463,71.0731707317073,63.3948292682927,74.1776341463415,63.1670487804878,65.878756097561,82.3463414634146,67.7189268292683,50.3631219512195,72.4981463414634,55.0230243902439,55.2209024390244,66.259512195122,70.99,76.2609756097561,80.2780487804878,81.7048780487805,48.9379268292683,74.7157804878049,51.1914878048781,59.1323658536585,74.2469268292683,69.4001707317073,65.4565609756098,67.5223658536585,72.6403414634147,70.3052926829268,73.6463414634147,75.1759512195122,64.2918292682927,57.7676829268293,71.159512195122,76.8361951219512,78.8414634146341,68.2275853658537,72.8108780487805,74.0744146341464,79.6243902439024,75.756487804878,71.669243902439,73.2503902439024,63.583512195122,56.7365853658537,58.2719268292683,59.2373658536585,55.633])

# Copy the code inside cell below and paste/run in your notebook to generate three new lists
Countries_2012_Dataset = list (["Aruba","Afghanistan","Angola","Albania","United Arab Emirates","Argentina","Armenia","Antigua and Barbuda","Australia","Austria","Azerbaijan","Burundi","Belgium","Benin","Burkina Faso","Bangladesh","Bulgaria","Bahrain","Bahamas, The","Bosnia and Herzegovina","Belarus","Belize","Bermuda","Bolivia","Brazil","Barbados","Brunei Darussalam","Bhutan","Botswana","Central African Republic","Canada","Switzerland","Chile","China","Cote d'Ivoire","Cameroon","Congo, Rep.","Colombia","Comoros","Cabo Verde","Costa Rica","Cuba","Cayman Islands","Cyprus","Czech Republic","Germany","Djibouti","Denmark","Dominican Republic","Algeria","Ecuador","Egypt, Arab Rep.","Eritrea","Spain","Estonia","Ethiopia","Finland","Fiji","France","Micronesia, Fed. Sts.","Gabon","United Kingdom","Georgia","Ghana","Guinea","Gambia, The","Guinea-Bissau","Equatorial Guinea","Greece","Grenada","Greenland","Guatemala","Guam","Guyana","Hong Kong SAR, China","Honduras","Croatia","Haiti","Hungary","Indonesia","India","Ireland","Iran, Islamic Rep.","Iraq","Iceland","Israel","Italy","Jamaica","Jordan","Japan","Kazakhstan","Kenya","Kyrgyz Republic","Cambodia","Kiribati","Korea, Rep.","Kuwait","Lao PDR","Lebanon","Liberia","Libya","St. Lucia","Liechtenstein","Sri Lanka","Lesotho","Lithuania","Luxembourg","Latvia","Macao SAR, China","Morocco","Moldova","Madagascar","Maldives","Mexico","Macedonia, FYR","Mali","Malta","Myanmar","Montenegro","Mongolia","Mozambique","Mauritania","Mauritius","Malawi","Malaysia","Namibia","New Caledonia","Niger","Nigeria","Nicaragua","Netherlands","Norway","Nepal","New Zealand","Oman","Pakistan","Panama","Peru","Philippines","Papua New Guinea","Poland","Puerto Rico","Portugal","Paraguay","French Polynesia","Qatar","Romania","Russian Federation","Rwanda","Saudi Arabia","Sudan","Senegal","Singapore","Solomon Islands","Sierra Leone","El Salvador","Somalia","Serbia","South Sudan","Sao Tome and Principe","Suriname","Slovak Republic","Slovenia","Sweden","Swaziland","Seychelles","Syrian Arab Republic","Chad","Togo","Thailand","Tajikistan","Turkmenistan","Timor-Leste","Tonga","Trinidad and Tobago","Tunisia","Turkey","Tanzania","Uganda","Ukraine","Uruguay","United States","Uzbekistan","St. Vincent and the Grenadines","Venezuela, RB","Virgin Islands (U.S.)","Vietnam","Vanuatu","West Bank and Gaza","Samoa","Yemen, Rep.","South Africa","Congo, Dem. Rep.","Zambia","Zimbabwe"])
Codes_2012_Dataset = list (["ABW","AFG","AGO","ALB","ARE","ARG","ARM","ATG","AUS","AUT","AZE","BDI","BEL","BEN","BFA","BGD","BGR","BHR","BHS","BIH","BLR","BLZ","BMU","BOL","BRA","BRB","BRN","BTN","BWA","CAF","CAN","CHE","CHL","CHN","CIV","CMR","COG","COL","COM","CPV","CRI","CUB","CYM","CYP","CZE","DEU","DJI","DNK","DOM","DZA","ECU","EGY","ERI","ESP","EST","ETH","FIN","FJI","FRA","FSM","GAB","GBR","GEO","GHA","GIN","GMB","GNB","GNQ","GRC","GRD","GRL","GTM","GUM","GUY","HKG","HND","HRV","HTI","HUN","IDN","IND","IRL","IRN","IRQ","ISL","ISR","ITA","JAM","JOR","JPN","KAZ","KEN","KGZ","KHM","KIR","KOR","KWT","LAO","LBN","LBR","LBY","LCA","LIE","LKA","LSO","LTU","LUX","LVA","MAC","MAR","MDA","MDG","MDV","MEX","MKD","MLI","MLT","MMR","MNE","MNG","MOZ","MRT","MUS","MWI","MYS","NAM","NCL","NER","NGA","NIC","NLD","NOR","NPL","NZL","OMN","PAK","PAN","PER","PHL","PNG","POL","PRI","PRT","PRY","PYF","QAT","ROU","RUS","RWA","SAU","SDN","SEN","SGP","SLB","SLE","SLV","SOM","SRB","SSD","STP","SUR","SVK","SVN","SWE","SWZ","SYC","SYR","TCD","TGO","THA","TJK","TKM","TLS","TON","TTO","TUN","TUR","TZA","UGA","UKR","URY","USA","UZB","VCT","VEN","VIR","VNM","VUT","PSE","WSM","YEM","ZAF","COD","ZMB","ZWE"])
Regions_2012_Dataset = list (["The Americas","Asia","Africa","Europe","Middle East","The Americas","Asia","The Americas","Oceania","Europe","Asia","Africa","Europe","Africa","Africa","Asia","Europe","Middle East","The Americas","Europe","Europe","The Americas","The Americas","The Americas","The Americas","The Americas","Asia","Asia","Africa","Africa","The Americas","Europe","The Americas","Asia","Africa","Africa","Africa","The Americas","Africa","Africa","The Americas","The Americas","The Americas","Europe","Europe","Europe","Africa","Europe","The Americas","Africa","The Americas","Africa","Africa","Europe","Europe","Africa","Europe","Oceania","Europe","Oceania","Africa","Europe","Asia","Africa","Africa","Africa","Africa","Africa","Europe","The Americas","The Americas","The Americas","Oceania","The Americas","Asia","The Americas","Europe","The Americas","Europe","Asia","Asia","Europe","Middle East","Middle East","Europe","Middle East","Europe","The Americas","Middle East","Asia","Asia","Africa","Asia","Asia","Oceania","Asia","Middle East","Asia","Middle East","Africa","Africa","The Americas","Europe","Asia","Africa","Europe","Europe","Europe","Asia","Africa","Europe","Africa","Asia","The Americas","Europe","Africa","Europe","Asia","Europe","Asia","Africa","Africa","Africa","Africa","Asia","Africa","Oceania","Africa","Africa","The Americas","Europe","Europe","Asia","Oceania","Middle East","Asia","The Americas","The Americas","Asia","Oceania","Europe","The Americas","Europe","The Americas","Oceania","Middle East","Europe","Europe","Africa","Middle East","Africa","Africa","Asia","Oceania","Africa","The Americas","Africa","Europe","Africa","Africa","The Americas","Europe","Europe","Europe","Africa","Africa","Middle East","Africa","Africa","Asia","Asia","Asia","Asia","Oceania","The Americas","Africa","Europe","Africa","Africa","Europe","The Americas","The Americas","Asia","The Americas","The Americas","The Americas","Asia","Oceania","Middle East","Oceania","Middle East","Africa","Africa","Africa","Africa"])

# %% [markdown]
# -------

# %% [markdown]
# ### Import the csv file called **"DemographicData.csv"** by choosing a convenient working directory
# [Back to Title](#SECTION-4---DataFrames-with-Python)

# %%
import pandas as pd
import os

import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline



import warnings
warnings.filterwarnings("ignore")

# Getting the working directory
print(os.getcwd()) # All good

os. chdir("C:\\Users\\Usuario\\Documents\\Python programming Course\\Data Frames")

stats = pd.read_csv("DemographicData.csv")
# Out:
# C:\Users\Usuario\Documents\Python programming Course

# %% [markdown]
# ---

# %% [markdown]
# ### Explore the DataSet:
# [Back to Title](#SECTION-4---DataFrames-with-Python)

# %% [markdown]
# ### Number of imported rows

# %%
len(stats)
# Out:
# 195

# %% [markdown]
# ### Name of the columns

# %%
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %% [markdown]
# ### Number of columns

# %%
len(stats.columns)
# Out:
# 5

# %% [markdown]
# ### Show the first five top rows

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# ### Show the first ten top rows

# %%
stats.head(10)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244         78.9000
# 1           Afghanistan          AFG      35.253          5.9000
# 2                Angola          AGO      45.985         19.1000
# 3               Albania          ALB      12.877         57.2000
# 4  United Arab Emirates          ARE      11.044         88.0000
# 5             Argentina          ARG      17.716         59.9000
# 6               Armenia          ARM      13.308         41.9000
# 7   Antigua and Barbuda          ATG      16.447         63.4000
# 8             Australia          AUS      13.200         83.0000
# 9               Austria          AUT       9.400         80.6188
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# ...

# %% [markdown]
# ### Show the last ten rows

# %%
stats.tail(10)
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 185  Virgin Islands (U.S.)          VIR      10.700            45.3
# 186                Vietnam          VNM      15.537            43.9
# 187                Vanuatu          VUT      26.739            11.3
# 188     West Bank and Gaza          PSE      30.394            46.6
# 189                  Samoa          WSM      26.172            15.3
# 190            Yemen, Rep.          YEM      32.947            20.0
# 191           South Africa          ZAF      20.850            46.5
# 192       Congo, Dem. Rep.          COD      42.394             2.2
# 193                 Zambia          ZMB      40.471            15.4
# 194               Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# ...

# %% [markdown]
# ### Show the columns info

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %% [markdown]
# ### Show the columns stats

# %%
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %% [markdown]
# ### Rename the columns without spaces

# %%
stats.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
       'IncomeGroup']

# %% [markdown]
# ### Filter the rows betwen 21 and 27

# %%
stats[21:28]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 21             Belize         BLZ     23.092          33.60
# 22            Bermuda         BMU     10.400          95.30
# 23            Bolivia         BOL     24.236          36.94
# 24             Brazil         BRA     14.931          51.04
# 25           Barbados         BRB     12.188          73.00
# 26  Brunei Darussalam         BRN     16.405          64.50
# 27             Bhutan         BTN     18.134          29.90
#
#             IncomeGroup
# 21  Upper middle income
# 22          High income
# 23  Lower middle income
# 24  Upper middle income
# 25          High income
# 26          High income
# 27  Lower middle income

# %% [markdown]
# ### Show the Data Frame Backwards

# %%
stats[::-1].head()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 194          Zimbabwe         ZWE     35.715           18.5
# 193            Zambia         ZMB     40.471           15.4
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 191      South Africa         ZAF     20.850           46.5
# 190       Yemen, Rep.         YEM     32.947           20.0
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income

# %% [markdown]
# ### Show one out of every twenty rows

# %%
stats[::10]
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %% [markdown]
# ### Extract a list with all the countries names

# %%
stats["CountryName"]
# Out:
# 0                               Aruba
# 1                         Afghanistan
# 2                              Angola
# 3                             Albania
# 4                United Arab Emirates
# 5                           Argentina
# 6                             Armenia
# 7                 Antigua and Barbuda
# 8                           Australia
# 9                             Austria
# 10                         Azerbaijan
# 11                            Burundi
# 12                            Belgium
# 13                              Benin
# 14                       Burkina Faso
# 15                         Bangladesh
# 16                           Bulgaria
# 17                            Bahrain
# 18                       Bahamas, The
# 19             Bosnia and Herzegovina
# 20                            Belarus
# 21                             Belize
# 22                            Bermuda
# 23                            Bolivia
# 24                             Brazil
# ...

# %% [markdown]
# ### Extract the **"CountryName"** and **"BirthRate"** columns

# %%
stats[["CountryName", "BirthRate"]]
# Out:
#                         CountryName  BirthRate
# 0                             Aruba     10.244
# 1                       Afghanistan     35.253
# 2                            Angola     45.985
# 3                           Albania     12.877
# 4              United Arab Emirates     11.044
# 5                         Argentina     17.716
# 6                           Armenia     13.308
# 7               Antigua and Barbuda     16.447
# 8                         Australia     13.200
# 9                           Austria      9.400
# 10                       Azerbaijan     18.300
# 11                          Burundi     44.151
# 12                          Belgium     11.200
# 13                            Benin     36.440
# 14                     Burkina Faso     40.551
# 15                       Bangladesh     20.142
# 16                         Bulgaria      9.200
# 17                          Bahrain     15.040
# 18                     Bahamas, The     15.339
# ...

# %% [markdown]
# ### Extract the rows 20 to 40 from the **"CountryName"** and **"BirthRate"** columns

# %%
stats[20:41][["CountryName", "BirthRate"]]
# Out:
#                  CountryName  BirthRate
# 20                   Belarus     12.500
# 21                    Belize     23.092
# 22                   Bermuda     10.400
# 23                   Bolivia     24.236
# 24                    Brazil     14.931
# 25                  Barbados     12.188
# 26         Brunei Darussalam     16.405
# 27                    Bhutan     18.134
# 28                  Botswana     25.267
# 29  Central African Republic     34.076
# 30                    Canada     10.900
# 31               Switzerland     10.200
# 32                     Chile     13.385
# 33                     China     12.100
# 34             Cote d'Ivoire     37.320
# 35                  Cameroon     37.236
# 36               Congo, Rep.     37.011
# 37                  Colombia     16.076
# 38                   Comoros     34.326
# 39                Cabo Verde     21.625
# 40                Costa Rica     15.022

# %% [markdown]
# ### Modify the DataSet
# [Back to Title](#SECTION-4---DataFrames-with-Python)

# %% [markdown]
# ### Do the product between **"BirthRate"** and **"InternetUsers"**

# %%
Result = stats.BirthRate * stats.InternetUsers

# %% [markdown]
# ### Create a new column whith the last result

# %%
stats["Result"] = Result

# %% [markdown]
# ### Drop the last created column

# %%
stats = stats.drop("Result", 1)

# %% [markdown]
# ### Filter the DataFrame
# [Back to Title](#SECTION-4---DataFrames-with-Python)

# %% [markdown]
# ### Extract all the rows with less than 10 **"InternetUsers"**

# %%
Filter = stats["InternetUsers"] < 10
stats[Filter]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 15                 Bangladesh         BGD     20.142           6.63
# 29   Central African Republic         CAF     34.076           3.50
# 34              Cote d'Ivoire         CIV     37.320           8.40
# 35                   Cameroon         CMR     37.236           6.40
# 36                Congo, Rep.         COG     37.011           6.60
# 38                    Comoros         COM     34.326           6.50
# 46                   Djibouti         DJI     25.486           9.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# ...

# %% [markdown]
# ### Extract the rows where **"BirthRate"** is less than 40

# %%
Filter2 = stats["BirthRate"] > 40
stats[Filter2]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %% [markdown]
# ### Extract the rows where **"BirthRate"** is less than 40 and **"InternetUsers"** is more than 20

# %%
Filter2 = stats["BirthRate"] > 40
Filter3 = stats["InternetUsers"] < 20
stats[Filter3 & Filter2]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# 156           Low income
# 167           Low income
# ...

# %% [markdown]
# ### Extract the rows where **"IncomeGroup"** is equal to *"High Income"*

# %%
Filter4 = stats["IncomeGroup"] == "High income"
stats[Filter4]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                    Aruba         ABW     10.244       78.90000  High income
# 4     United Arab Emirates         ARE     11.044       88.00000  High income
# 5                Argentina         ARG     17.716       59.90000  High income
# 7      Antigua and Barbuda         ATG     16.447       63.40000  High income
# 8                Australia         AUS     13.200       83.00000  High income
# 9                  Austria         AUT      9.400       80.61880  High income
# 12                 Belgium         BEL     11.200       82.17020  High income
# 17                 Bahrain         BHR     15.040       90.00004  High income
# 18            Bahamas, The         BHS     15.339       72.00000  High income
# 22                 Bermuda         BMU     10.400       95.30000  High income
# 25                Barbados         BRB     12.188       73.00000  High income
# ...

# %% [markdown]
# ### Extract all the unique values in **"IncomeGroup"**

# %%
stats.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %% [markdown]
# ### Find the value in cell (3,4)

# %%
stats.head(20)
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244       78.90000
# 1              Afghanistan         AFG     35.253        5.90000
# 2                   Angola         AGO     45.985       19.10000
# 3                  Albania         ALB     12.877       57.20000
# 4     United Arab Emirates         ARE     11.044       88.00000
# 5                Argentina         ARG     17.716       59.90000
# 6                  Armenia         ARM     13.308       41.90000
# 7      Antigua and Barbuda         ATG     16.447       63.40000
# 8                Australia         AUS     13.200       83.00000
# 9                  Austria         AUT      9.400       80.61880
# 10              Azerbaijan         AZE     18.300       58.70000
# 11                 Burundi         BDI     44.151        1.30000
# 12                 Belgium         BEL     11.200       82.17020
# ...

# %%
stats.iat[3,4]
# Out:
# 'Upper middle income'

# %%
stats.at[3,"IncomeGroup"]
# Out:
# 'Upper middle income'

# %% [markdown]
# ### Find the value in **"CountryName"** with index number = 15

# %%
stats.at[15,"CountryName"]
# Out:
# 'Bangladesh'

# %% [markdown]
# ### Seaborn visualization
# [Back to Title](#SECTION-4---DataFrames-with-Python)

# %% [markdown]
# ### Build a histogram plot with 30 bins who shows **"InternerUsers"**

# %%
plt.rcParams["figure.figsize"] = 10,7
plot1 = sns.distplot(stats["InternetUsers"],bins=30)

# %% [markdown]
# ### Build a boxplot who shows **"IncomeGroup"** in the x axes and **"BirthRate"** in the y axes

# %%
plot2 = sns.boxplot(data = stats,x = "IncomeGroup", y = "InternetUsers")

# %% [markdown]
# ### Build a scatterplot who shows **"InternerUsers"** vs **"BirthRate"** with the following characteristics:

# %% [markdown]
# 1. No regression line.
# 1. Must have **"IncomeGroup"** categorized by colors.
# 1. Size of the grafic = 10.
# 1. Increase the markers size using *keyword arguments*.

# %%
plot3 = sns.lmplot(data = stats, y = "InternetUsers", x = "BirthRate", hue = "IncomeGroup", fit_reg=False, size= 10, \
                   scatter_kws = {"s":200} )

# %% [markdown]
# ### Extra exercise:
# [Back to Title](#SECTION-4---DataFrames-with-Python)

# %% [markdown]
# 1. Using the extra list above, must join them in the old Dataframe and create a newone with all the correct information
# 1. Categorized by **"CountryRegions"**
# 1. Create one plot for each year

# %%
# Building the DataFrames:

stats_LifeExpectancy = pd.DataFrame({"CountryCode":np.array(Country_Code), \
                                    "LifeExpectancy1960":np.array(Life_Expectancy_At_Birth_1960), \
                                    "LifeExpectancy2013":np.array(Life_Expectancy_At_Birth_2013)})

stats_CountryRegion = pd.DataFrame({"Coutries":np.array(Countries_2012_Dataset), \
                                    "CountryCode":np.array(Codes_2012_Dataset), \
                                    "Regions":np.array(Regions_2012_Dataset)})

# %%
# Merge the two DataFrames:

stats2 = pd.merge(right = stats_LifeExpectancy, left = stats_CountryRegion, on = "CountryCode", how = "inner")

# %%
# Merge the other two DataFrames:

stats3 = pd.merge(right = stats2, left = stats, on = "CountryCode", how = "inner")

# %%
stats3.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup              Coutries       Regions  \
# 0          High income                 Aruba  The Americas
# 1           Low income           Afghanistan          Asia
# 2  Upper middle income                Angola        Africa
# 3  Upper middle income               Albania        Europe
# 4          High income  United Arab Emirates   Middle East
#
#    LifeExpectancy1960  LifeExpectancy2013
# 0           65.569366           75.328659
# 1           32.328512           60.028268
# 2           32.984829           51.866171
# 3           62.254366           77.537244
# ...

# %%
# Drop the duplicate column

stats3 = stats3.drop("Coutries", axis=1 )

# %%
plot_1960 =  sns.lmplot(data = stats3, x = "BirthRate", y = "LifeExpectancy1960", hue = "Regions", size = 10, \
                    scatter_kws={"s":200}, fit_reg = False)

# %%
plot_2015 =  sns.lmplot(data = stats3, x = "BirthRate", y = "LifeExpectancy2013", hue = "Regions", size = 10, \
                    scatter_kws={"s":200}, fit_reg = False)

# %% [markdown]
# ---

# %% [markdown]
# # SECTION 5 - Advance Visulization

# %% [markdown]
# # Advance Visualization Tutorial - Movies Frame Analisis
#
# ## Index:
#
# 1. [>>>](#Import-csv-using-pandas-package.)*Import* csv using pandas package.
# 1. [>>>](#Exploring-the-"Movie-Ratings.csv":)*Exploring* the [**"Movie-Ratings.csv"**](https://www.superdatascience.com/pages/python):
#     1. Getting the first 5 rows.
#     1. Getting some information about the data type of the columns.
#     1. Getting a list of the column names.
#     1. Getting stats of the numeric columns.
#     1. Changing the name of the columns.
#     1. Changing the datatype of the columns to match its content.
# 1. [>>>](#Draw-a-jointplot-showing-"AudienceRating"-vs-"CriticRating".)Draw a *jointplot* showing **"AudienceRating"** vs **"CriticRating"**.
# 1. [>>>](#Draw-a-hexagonal-jointplot-showing-"AudienceRating"-vs-"CriticRating".)Draw a *hexagonal jointplot* showing **"AudienceRating"** vs **"CriticRating"**.
# 1. [>>>](#Draw-a-histogram-plot-showing-"CriticRating"-distribution.)Draw a *histogram plot* showing **"CriticRating" distribution**.
# 1. [>>>](#Draw-a-histogram-plot-showing-"AudienceRating"-distribution.)Draw a *histogram plot* showing **"AudienceRating"** distribution.
# 1. [>>>](#Draw-a-staked-histogram-to-show-the-"BudgetMillions"-distribution-by-the-"Genre"-category:)Draw a *staked histogram* to show the **"BudgetMillions"** distribution by the **"Genre"** category:
#     1. Staked histogram with aplyed color palet.
#     1. Title formatting.
#     1. x and y labels formatting.
#     1. xtick and ytick formatting.
#     1. Leyend formatting.
# 1. [>>>](#Draw-a-kernel-density-estimate-plot-showing-the-relationship-betwen-"AudienceRatieng"-and-"CriticRating".)Draw a  *kernel density estimate* plot showing the relationship betwen **"AudienceRatieng"** and **"CriticRating"**.
# 1. [>>>](#Create-a-two-subplots-with-a-kernel-density-estimate-plot-for-each-one-showing-the-difference-between-"AudienceRatieng"-and-"CriticRating"-vs-"BudgetMillions".) Create a two *subplots* with a *kernel density estimate* plot for each one showing the difference between **"AudienceRatieng"** and **"CriticRating"** vs **"BudgetMillions"**.
# 1. [>>>](#Draw-a-violin-plot-showing-"CriticRating"-vs-"Genre".)Draw a *violin plot* showing **"CriticRating"** vs **"Genre"**.
# 1. [>>>](#Draw-a-violin-plot-showing-"AudienceRatieng"-vs-"Genre".)Draw a *violin plot* showing **"AudienceRatieng"** vs **"Genre"**.
# 1. [>>>](#Create-a-FacetGrid-to-show-the-change-in-the-"AudienceRating"-vs-"CriticRating"-across-all-Genres(y-axes)-and-all-years(x-axes)-in-the-DataSet)Create a *FacetGrid* to show the change in the **"AudienceRating"** vs **"CriticRating"** across all Genres(y axes) and all years(x axes) in the DataSet; this plots must have:
#     1. Diagonal discontinued line bettwen the two halfs of each plot.
#     1. Leyend for the **"Genre"** category.
#     1. Points of the scatterplots with the correct format.
# 1. [>>>](#Create-a-FacetGrid-to-show-the-change-in-the-"BudgetMillions"-distribution-across-all-Genres(y-axes)-and-all-years(x-axes)-in-the-DataSet.)Create a *FacetGrid* to show the change in the **"BudgetMillions"** distribution across all Genres(y axes) and all years(x axes) in the DataSet.
# 1. [>>>](#Create-a-dashboard-who-shows-all-the-most-important-plots-in-order-to-perform-a-correct-analysis-of-these-DataSet.-Make-sure-of-creating-at-least-one-of-the-visualizations-comming-from-pyplot-instead-of-seaborn.)Create a *dashboard* who shows all the most important plots in order to perform a correct analysis of these DataSet. Make sure of creating at least one of the visualizations comming from pyplot instead of seaborn.
# 1. [>>>](#Import-the-dataset-and-use-the-data-to-recreate-the-grafic-in-the-image-bellow-called-Boxplot---Movies-Domestic-Gross.png-wich-can-be-found-in-our-working-directory)*Import* the dataset [**"Section6-Homework-Data.csv"**](https://www.superdatascience.com/pages/python) and use the data to recreate the grafic in the image bellow called **"Boxplot - Movies Domestic Gross.png"** wich can be found in our working directory.
#
# *the data fot this tutorial can be download from [here.](https://www.superdatascience.com/pages/python)*

# %%
from IPython.display import Image
i = Image(filename='C:\\Users\\Usuario\\Documents\\Python programming Course\\AdvanceVisualization\\Boxplot - Movies Domestic Gross.jpg')
i

# %% [markdown]
# ---

# %% [markdown]
# ### Imports needed

# %%
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
os. chdir("C:\\Users\\Usuario\\Documents\\Python programming Course\\AdvanceVisualization")

# %% [markdown]
# ### Import csv using pandas package.
# [Back to Title](#SECTION-5---Advance-Visulization)

# %%
movies = pd.read_csv("Movie-Ratings.csv")

# %% [markdown]
# ### Exploring the "Movie-Ratings.csv":
# [Back to Title](#SECTION-5---Advance-Visulization)

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film                         559 non-null object
# Genre                        559 non-null object
# Rotten Tomatoes Ratings %    559 non-null int64
# Audience Ratings %           559 non-null int64
# Budget (million $)           559 non-null int64
# Year of release              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %% [markdown]
# #### Changing the name of the columns

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating',
       'BudgetMillions', 'Year']

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %% [markdown]
# #### Changing the datatype to "category"

# %%
movies.Film = movies.Film.astype("category")
movies.Year = movies.Year.astype("category")
movies.Genre = movies.Genre.astype("category")

# %% [markdown]
# ### Draw a jointplot showing "AudienceRating" vs "CriticRating".
# [Back to Title](#SECTION-5---Advance-Visulization)

# %%
jplot1 = sns.jointplot(data = movies, y = "AudienceRating", x = "CriticRating", color = "blue")

# %% [markdown]
# ### Draw a hexagonal jointplot showing "AudienceRating" vs "CriticRating".
#
# This type of plot shows a better clustering data
#
# [Back to Title](#SECTION-5---Advance-Visulization)

# %%
jplot1 = sns.jointplot(data = movies, y = "AudienceRating", x = "CriticRating", kind='hex', color = "blue")

# %% [markdown]
# ### Draw a histogram plot showing "CriticRating" distribution.
# [Back to Title](#SECTION-5---Advance-Visulization)

# %%
hist1 = sns.distplot( movies.CriticRating, bins = 15)

# %% [markdown]
# ### Draw a histogram plot showing "AudienceRating" distribution.
# [Back to Title](#SECTION-5---Advance-Visulization)

# %%
hist2 = sns.distplot( movies.AudienceRating, bins = 15)

# %% [markdown]
# ### Draw a staked histogram to show the "BudgetMillions" distribution by the "Genre" category:
# [Back to Title](#SECTION-5---Advance-Visulization)

# %%
sns.set_style("whitegrid")   # Background of the plot

# Plot for loop

list1 = list()
myLabel = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    myLabel.append(gen)
    
# Color list
col_list = list(["xkcd:ultramarine blue", "xkcd:indigo blue", "xkcd:blue with a hint of purple", "xkcd:purple blue", \
                 "xkcd:bluish purple", "xkcd:purpley", "xkcd:pastel purple"])
    
# Size of the plot
f, ax = plt.subplots()   # Unique SubPlot, these is a very generic approach to change the size of any plot  
f.set_size_inches(11.7, 8.27)   # This is an A4 paper size

# Plot
h = plt.hist(list1, bins = 15, stacked = True, label = myLabel, rwidth = 1, color = col_list)

# Leyend
plt.legend(prop = {"size":20}, frameon = True, fancybox = True, shadow = True, framealpha = 1)

# Title
plt.title("Budget in Millions", fontsize = 50, color = "dodgerblue", fontname = "console")

# Axes numbers format
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)

# Axes Labels
plt.ylabel("Number of Movies", fontsize = 30, color = "firebrick", fontname = "console")
plt.xlabel("Budget", fontsize = 30, color = "xkcd:kelley green", fontname = "console")

# Show only the plot
plt.show()

# %% [markdown]
# ### Draw a kernel density estimate plot showing the relationship betwen "AudienceRatieng" and "CriticRating".
# [Back to Title](#SECTION-5---Advance-Visulization)

# %%
# Single subplot with size in inches
f, ax = plt.subplots()
f.set_size_inches(11.7, 8.27)

# Two plots overlaped 
k1b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, cmap = "Reds")
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade = True, shade_lowest = False, \
                cmap = "Reds")

# %% [markdown]
# ---

# %% [markdown]
# ### All the colour maps for the plots:
#
# Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r,RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, pectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, icefire, icefire_r, inferno, inferno_r, jet, jet_r, magma, magma_r, mako, mako_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, rocket, rocket_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, twilight, twilight_r, twilight_shifted, twilight_shifted_r, viridis, viridis_r, vlag, vlag_r, winter, winter_r <s

# %% [markdown]
# ---

# %% [markdown]
# ### Create a two subplots with a kernel density estimate plot for each one showing the difference between "AudienceRatieng" and "CriticRating" vs "BudgetMillions".
# [Back to Title](#SECTION-5---Advance-Visulization)

# %%
# Subplots
f, axes = plt.subplots(1, 2, figsize = (12,6), sharey = True, sharex = True)

# Left plot
k1b = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, cmap = "cool", ax = axes[0])
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, shade = True, shade_lowest = False, \
                cmap = "cool", ax = axes[0])

# Right plot
k2b = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, cmap = "cool", ax = axes[1])
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, shade = True, shade_lowest = False, \
                cmap = "cool", ax = axes[1])

# Axes limits
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
k1.set(ylim=(-10,110))
k2.set(ylim=(-10,110))
# Out:
# [(-10, 110)]

# %% [markdown]
# ### Draw a violin plot showing "CriticRating" vs "Genre".
# [Back to Title](#SECTION-5---Advance-Visulization)

# %%
f, ax = plt.subplots()
f.set_size_inches(11.7, 8.27)
vln = sns.violinplot(data = movies, x = "Genre", y = "CriticRating")

# %% [markdown]
# ### Draw a *violin plot* showing **"AudienceRatieng"** vs **"Genre"**.
# [Back to Title](#SECTION-5---Advance-Visulization)

# %%
f, ax = plt.subplots()
f.set_size_inches(11.7, 8.27)
vln = sns.violinplot(data = movies, x = "Genre", y = "AudienceRating")

# %% [markdown]
# ### Create a *FacetGrid* to show the change in the **"AudienceRating"** vs **"CriticRating"** across all Genres(y axes) and all years(x axes) in the DataSet
# [Back to Title](#SECTION-5---Advance-Visulization)

# %%
# Set white background
sns.set_style("white")

# Empty facetgrid
g = sns.FacetGrid(movies, row = "Genre", col = "Year", hue = "Genre")

# Skatter plot arguments for the markers format
kws = dict(s = 150, linewidth = 0.5, edgecolor = "black")

# Plot for the facetgrid
g = g.map(plt.scatter, "CriticRating", "AudienceRating", **kws)


# Axes limits
g.set(xlim = (0,100), ylim = (0,100))

# Diagonal line
for ax in g.axes.flat:
    ax.plot((0,100), (0,100), c = "gray", ls = "--")

# Leyend
g.add_legend()
plt.show()

# %% [markdown]
# ### Create a *FacetGrid* to show the change in the **"BudgetMillions"** distribution across all Genres(y axes) and all years(x axes) in the DataSet.
# [Back to Title](#SECTION-5---Advance-Visulization)

# %%
# Empty facetgrid
g = sns.FacetGrid(data = movies, row = "Genre", col = "Year", hue = "Genre")

# Plot for the facetgrid
g = g.map(plt.hist, "BudgetMillions")

# Leyend
g.add_legend()
plt.show()

# %% [markdown]
# ### Create a *dashboard* who shows all the most important plots in order to perform a correct analysis of these DataSet. Make sure of creating at least one of the visualizations comming from pyplot instead of seaborn.
# [Back to Title](#SECTION-5---Advance-Visulization)

# %%
# Set background color
sns.set_style("dark",{"axes.facecolor":"black"})
f, axes = plt.subplots(3,2, figsize = (20,20))

# Plot [0,0]
k1b = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, cmap = "cool", ax = axes[0,0],)
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, shade = True, shade_lowest = False, \
                cmap = "inferno", ax = axes[0,0])
k1.set(xlim=(-20,160))


# Plot [0,1]
k2b = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, cmap = "cool", ax = axes[0,1])
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, shade = True, shade_lowest = False, \
                cmap = "inferno", ax = axes[0,1])
k2.set(xlim=(-20,160))

# Plot [1,0]
vln = sns.violinplot(data = movies, x = "Genre", y = "BudgetMillions", palette = "YlOrRd", ax = axes[1,0])

# Plot [1,1]
vln = sns.violinplot(data = movies, x = "Year", y = "BudgetMillions", palette = "YlOrRd", ax = axes[1,1])

# Plot [2,0]
P1b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, cmap = "Blues_r", ax = axes[2,0])
P1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade = True, shade_lowest = False, \
                cmap = "Blues_r", ax = axes[2,0])

# Plot [2,1]
axes[2,1].hist(movies.CriticRating, bins = 15)

plt.show()

# %% [markdown]
# ### Import the dataset and use the data to recreate the grafic in the image bellow called Boxplot - Movies Domestic Gross.png wich can be found in our working directory
# [Back to Title](#SECTION-5---Advance-Visulization)

# %%
from IPython.display import Image
i = Image(filename='C:\\Users\\Usuario\\Documents\\Python programming Course\\AdvanceVisualization\\Boxplot - Movies Domestic Gross.jpg')
i

# %%
# Import the DataFrame

movies2 = pd.read_csv("HomeworkData.csv", sep=',', encoding='latin-1')

# %%
movies2.head()
# Out:
#   Day of Week                 Director   Genre        Movie Title  \
# 0      Friday                Brad Bird  action       Tomorrowland
# 1      Friday              Scott Waugh  action     Need for Speed
# 2      Friday           Patrick Hughes  action  The Expendables 3
# 3      Friday  Phil Lord, Chris Miller  comedy     21 Jump Street
# 4      Friday          Roland Emmerich  action   White House Down
#
#   Release Date               Studio Adjusted Gross ($mill)  Budget ($mill)  \
# 0   22/05/2015  Buena Vista Studios                  202.1           170.0
# 1   14/03/2014  Buena Vista Studios                  204.2            66.0
# 2   15/08/2014            Lionsgate                  207.1           100.0
# 3   16/03/2012                 Sony                  208.8            42.0
# 4   28/06/2013                 Sony                  209.7           150.0
#
#   Gross ($mill)  IMDb Rating  MovieLens Rating Overseas ($mill)  Overseas%  \
# ...

# %%
# Changing the name
movies2.columns = ['DayOfWeek', 'Director', 'Genre', 'MovieTitle', 'ReleaseDate',
       'Studio', 'AdjustedGross', 'Budget', 'Gross',
       'IMDbRating', 'MovieLensRating', 'Overseas', 'Overseas%',
       'Profit', 'Profit%', 'Runtime(min)', 'US',
       'Gross%US']

# %%
# Studio and Genre Filter
movies2_filter = movies2[(movies2.Genre == "action") | (movies2.Genre == "comedy")| (movies2.Genre == "adventure")| (movies2.Genre == "animation")| (movies2.Genre == "drama")]
movies2_filter2 = movies2_filter[(movies2_filter.Studio == "Buena Vista Studios") | (movies2_filter.Studio == "Sony") | (movies2_filter.Studio == "Universal") | (movies2_filter.Studio == "WB") | (movies2_filter.Studio == "Paramount Pictures	") | (movies2_filter.Studio == "Fox")]

# %%
sns.set_style("darkgrid", {"palette": "muted", "color_codes": "True"})

# %%
f, ax = plt.subplots()
f.set_size_inches(11.7, 8.27)
sns.set_style("darkgrid", {"palette": "muted", "color_codes": "True"})
plot = sns.boxplot(data = movies2_filter2, x = "Genre", y = 'Gross%US', orient = "v", color = "lightgrey", showfliers = False)
plt.setp(ax.artists, alpha = 0.5)
plot2 = sns.stripplot(data = movies2_filter2, x = "Genre", y = "Gross%US", jitter=True, hue = "Studio", size = 10, )
plt.legend(loc ="upper left",bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# #### Copyright
#
# [Super Data Science](http://www.superdatascience.com)
#
# Copyright: These datasets were prepared using publicly available data.
#            However, theses scripts are subject to Copyright Laws.
#            If you wish to use these Python scripts outside of the Python Programming Course
#            by Kirill Eremenko, you may do so by referencing www.superdatascience.com in your work.
#
# [Back to Title](#SECTION-5---Advance-Visulization)
